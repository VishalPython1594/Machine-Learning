# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
training = pd.read_csv('har_train.csv')
test = pd.read_csv('har_validate.csv')

# %%
training.shape
# Out:
# (13737, 53)

# %%
test.shape
# Out:
# (5885, 53)

# %%
training.describe()
# Out:
#           roll_belt    pitch_belt      yaw_belt  total_accel_belt  \
# count  13737.000000  13737.000000  13737.000000      13737.000000
# mean      64.503131      0.191794    -10.941653         11.317973
# std       62.768030     22.363296     95.374331          7.744534
# min      -28.900000    -54.900000   -180.000000          0.000000
# 25%        1.100000      1.670000    -88.300000          3.000000
# 50%      114.000000      5.260000    -12.700000         17.000000
# 75%      123.000000     14.800000     13.600000         18.000000
# max      162.000000     60.300000    179.000000         28.000000
#
#        gyros_belt_x  gyros_belt_y  gyros_belt_z  accel_belt_x  accel_belt_y  \
# count  13737.000000  13737.000000  13737.000000  13737.000000  13737.000000
# mean      -0.004831      0.040013     -0.130328     -5.424620     30.152362
# std        0.206729      0.078435      0.241559     29.697752     28.560242
# ...

# %%
test.describe()
# Out:
#          roll_belt   pitch_belt     yaw_belt  total_accel_belt  gyros_belt_x  \
# count  5885.000000  5885.000000  5885.000000       5885.000000   5885.000000
# mean     64.183263     0.570192   -11.819918         11.300085     -0.007370
# std      62.713506    22.322734    94.776716          7.737757      0.208729
# min     -28.600000   -55.800000  -179.000000          1.000000     -0.980000
# 25%       1.080000     1.930000   -88.300000          3.000000     -0.030000
# 50%     113.000000     5.360000   -14.300000         17.000000      0.030000
# 75%     123.000000    15.300000     7.390000         18.000000      0.110000
# max     162.000000    60.100000   179.000000         29.000000      2.020000
#
#        gyros_belt_y  gyros_belt_z  accel_belt_x  accel_belt_y  accel_belt_z  \
# count   5885.000000   5885.000000   5885.000000   5885.000000   5885.000000
# mean       0.038595     -0.131028     -5.991674     30.160748    -72.232625
# ...

# %%
training.tail(50)
# Out:
#       classe  roll_belt  pitch_belt  yaw_belt  total_accel_belt  gyros_belt_x  \
# 13687      E       1.26        6.85     -91.6                 1          0.16
# 13688      E       0.00        6.94     -91.7                 1          0.11
# 13689      E      -1.93        6.76     -91.9                 2          0.03
# 13690      E      -3.10        6.54     -91.9                 2         -0.03
# 13691      E      -5.52        5.90     -91.9                 3         -0.10
# 13692      E      -5.88        5.77     -91.9                 3         -0.14
# 13693      E      -7.09        4.63     -92.1                 4         -0.19
# 13694      E      -7.08        3.63     -92.1                 4         -0.06
# 13695      E      -7.01        3.54     -92.1                 4          0.02
# 13696      E      -5.10        4.02     -92.7                 4          0.16
# 13697      E      -4.48        4.57     -92.6                 4          0.11
# ...

# %%
training['classe'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E'], dtype=object)

# %%
#Create X and Y

# %%
x_train = training.drop('classe',axis=1)
y_train = training.loc[:,'classe']

x_test = test.drop('classe',axis=1)
y_test = test.loc[:,'classe']

# %%
# Init the Gaussian Classifier

# %%
model = GaussianNB()

# Train the Model
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
# Predict Output

# %%
pred = model.predict(x_test)
print(pred[:150])
# Out:
# ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C'
#  'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'C' 'D' 'D' 'E' 'E' 'E' 'E'
#  'D' 'C' 'C' 'C' 'D' 'C' 'D' 'D' 'D' 'D' 'D' 'E' 'E' 'E' 'E' 'E' 'E' 'D'
#  'D' 'D' 'D' 'D' 'D' 'D' 'D' 'D' 'C' 'C' 'C' 'C' 'D' 'D' 'D' 'D' 'D' 'D'
#  'D' 'D' 'D' 'D' 'D' 'D']

# %%
#Plot Confusion Matrix

# %%
plt.figure(figsize = (10,8))
mat = confusion_matrix(pred,y_test)
names = np.unique(pred)
sns.heatmap(mat, square=True, annot=True, xticklabels=names, yticklabels=names, cbar=False, fmt = 'd')
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.plot()
# Out:
# []

# %%
np.unique(pred)
# Out:
# array(['A', 'B', 'C', 'D', 'E'], dtype='<U1')

# %%
# Importing the dependencies
from sklearn import metrics

#Predicted Values
y_pred = pred

#Actual Values
y_act = y_test

# Printing the confusion matrix
# The columns will show the instances predicted for each label,
# and the rows will show the actual number of instances for each label.

print(metrics.confusion_matrix(y_test,pred,labels=['A','B','C','D','E']))

# Printing the precision and recall, among other metrics

print(metrics.classification_report(y_test,pred,labels=['A','B','C','D','E']))
# Out:
# [[1070   95  262  212   35]
#  [ 127  685  145   76  106]
#  [ 223  106  512  136   49]
#  [ 102   35  271  441  115]
#  [  51  239   95  143  554]]
#               precision    recall  f1-score   support
#
#            A       0.68      0.64      0.66      1674
#            B       0.59      0.60      0.60      1139
#            C       0.40      0.50      0.44      1026
#            D       0.44      0.46      0.45       964
#            E       0.64      0.51      0.57      1082
#
#     accuracy                           0.55      5885
#    macro avg       0.55      0.54      0.54      5885
# weighted avg       0.57      0.55      0.56      5885

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[1070   95  262  212   35]
#  [ 127  685  145   76  106]
#  [ 223  106  512  136   49]
#  [ 102   35  271  441  115]
#  [  51  239   95  143  554]]

# %%
print(metrics.classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.68      0.64      0.66      1674
#            B       0.59      0.60      0.60      1139
#            C       0.40      0.50      0.44      1026
#            D       0.44      0.46      0.45       964
#            E       0.64      0.51      0.57      1082
#
#     accuracy                           0.55      5885
#    macro avg       0.55      0.54      0.54      5885
# weighted avg       0.57      0.55      0.56      5885
